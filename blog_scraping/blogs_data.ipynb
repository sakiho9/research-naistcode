# %% [markdown]
# # アメブロ　ダイエット記録
# ### スクレイピング期間：2024 8/3-5

# %%
# データの読み込み
import pandas as pd

df_1 = pd.read_csv('blogs_1.csv')
df_2 = pd.read_csv('blogs_2.csv')
df_3 = pd.read_csv('blogs_3.csv')
df_4 = pd.read_csv('blogs_4.csv')
df_5 = pd.read_csv('blogs_5.csv')
df_6 = pd.read_csv('blogs_6.csv')
df_7 = pd.read_csv('blogs_7.csv')
df_8 = pd.read_csv('blogs_8.csv')
df_9 = pd.read_csv('blogs_9.csv')
df_10 = pd.read_csv('blogs_10.csv')
df_11 = pd.read_csv('blogs_11.csv')
df_12 = pd.read_csv('blogs_12.csv')
df_13 = pd.read_csv('blogs_13.csv')
df_14 = pd.read_csv('blogs_14.csv')
df_15 = pd.read_csv('blogs_15.csv')
df_16 = pd.read_csv('blogs_16.csv')
df_17 = pd.read_csv('blogs_17.csv')
df_18 = pd.read_csv('blogs_18.csv')
df_19 = pd.read_csv('blogs_19.csv')
df_20 = pd.read_csv('blogs_20.csv')
df_21 = pd.read_csv('blogs_21.csv')
df_22 = pd.read_csv('blogs_22.csv')
df_23 = pd.read_csv('blogs_23.csv')
df_24 = pd.read_csv('blogs_24.csv')
df_25 = pd.read_csv('blogs_25.csv')
df_26 = pd.read_csv('blogs_26.csv')
df_27 = pd.read_csv('blogs_27.csv')
df_28 = pd.read_csv('blogs_28.csv')
df_29 = pd.read_csv('blogs_29.csv')
df_30 = pd.read_csv('blogs_30.csv')
df_31 = pd.read_csv('blogs_31.csv')
df_32 = pd.read_csv('blogs_32.csv')
df_33 = pd.read_csv('blogs_33.csv')
df_34 = pd.read_csv('blogs_34.csv')
df_35 = pd.read_csv('blogs_35.csv')
df_36 = pd.read_csv('blogs_36.csv')
df_37 = pd.read_csv('blogs_37.csv')
df_38 = pd.read_csv('blogs_38.csv')
df_39 = pd.read_csv('blogs_39.csv')
df_40 = pd.read_csv('blogs_40.csv')
df_41 = pd.read_csv('blogs_41.csv')
df_42 = pd.read_csv('blogs_42.csv')
df_43 = pd.read_csv('blogs_43.csv')
df_44 = pd.read_csv('blogs_44.csv')
df_45 = pd.read_csv('blogs_45.csv')
df_46 = pd.read_csv('blogs_46.csv')
df_47 = pd.read_csv('blogs_47.csv')
df_48 = pd.read_csv('blogs_48.csv')
df_49 = pd.read_csv('blogs_49.csv')
df_50 = pd.read_csv('blogs_50.csv')
df_51 = pd.read_csv('blogs_51.csv')
df_52 = pd.read_csv('blogs_52.csv')
df_53 = pd.read_csv('blogs_53.csv')

# %%
# データフレームを結合
df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17, df_18, df_19, df_20, df_21, df_22, df_23, df_24, df_25, df_26, df_27, df_28, df_29, df_30, df_31, df_32, df_33, df_34, df_35, df_36, df_37, df_38, df_39, df_40, df_41, df_42, df_43, df_44, df_45, df_46, df_47, df_48, df_49, df_50, df_51, df_52, df_53], ignore_index=True)

# 重複行を削除
df = df.drop_duplicates()

# インデックスをリセット
df.reset_index(drop=True, inplace=True)

# %%
# ユーザ数を確認
print('ユーザ数：', len(df['user'].unique()), '人')

# データ数を確認
print('データ数：', len(df), '件')
# Out:
# ユーザ数： 826 人
# データ数： 407668 件

# %%
# データの保存
df.to_csv('diet_blogs.csv', index=False)

# %%
import pandas as pd

# %%
# データの読み込み
df = pd.read_csv('diet_blogs.csv')
df
# Out:
#                          blog_title  sex  age        user  \
# 0       アラフォーボブ子の16時間断食オートファジーダイエット   女性  NaN     bobdiet
# 1       アラフォーボブ子の16時間断食オートファジーダイエット   女性  NaN     bobdiet
# 2       アラフォーボブ子の16時間断食オートファジーダイエット   女性  NaN     bobdiet
# 3       アラフォーボブ子の16時間断食オートファジーダイエット   女性  NaN     bobdiet
# 4       アラフォーボブ子の16時間断食オートファジーダイエット   女性  NaN     bobdiet
# ...                             ...  ...  ...         ...
# 407663                   過食気味な私のブログ  NaN  NaN  yarmid0130
# 407664                   過食気味な私のブログ  NaN  NaN  yarmid0130
# 407665                   過食気味な私のブログ  NaN  NaN  yarmid0130
# 407666                   過食気味な私のブログ  NaN  NaN  yarmid0130
# 407667                   過食気味な私のブログ  NaN  NaN  yarmid0130
#
#                                                url        date  \
# 0                       https://ameblo.jp/bobdiet/  2024-08-04
# 1            https://ameblo.jp/bobdiet/page-2.html  2024-08-04
# 2            https://ameblo.jp/bobdiet/page-3.html  2024-08-03
# ...

# %%
df['user'].value_counts()
# Out:
# user
# nekomeishi-kirari    10854
# remuera-nz            6589
# akibaboxinggym        6003
# agnesdigital59        5343
# kuromame3298daizu     5259
#                      ...
# thaleia222               1
# sasami317515             1
# yukicandy-apple          1
# marysmomo                1
# pumix777                 1
# Name: count, Length: 825, dtype: int64

# %%
# 'text'に'摂食障害'が含まれるデータを抽出
df_filtered = df[df['text'].str.contains('摂食障害', na=False)]

# インデックスをリセット
df_filtered.reset_index(drop=True, inplace=True)

print(df_filtered)
# Out:
#                                    blog_title  sex  age                  user  \
# 0    腹筋運動なんてしなくてよろし♡意識だけ美姿勢ダイエット♡勝手に痩せる体になる秘密  NaN  NaN    precious-being-day
# 1                         K25ダイエット 正しい知識は武器です   女性  NaN       happybeauty0628
# 2                         K25ダイエット 正しい知識は武器です   女性  NaN       happybeauty0628
# 3                         K25ダイエット 正しい知識は武器です   女性  NaN       happybeauty0628
# 4                         K25ダイエット 正しい知識は武器です   女性  NaN       happybeauty0628
# ..                                        ...  ...  ...                   ...
# 399   痩身ファスティング小顔専門店/BONHEUR-ボヌール-名古屋覚王山店のブログ  NaN  NaN  salon-bonheur-nagoya
# 400   痩身ファスティング小顔専門店/BONHEUR-ボヌール-名古屋覚王山店のブログ  NaN  NaN  salon-bonheur-nagoya
# 401   痩身ファスティング小顔専門店/BONHEUR-ボヌール-名古屋覚王山店のブログ  NaN  NaN  salon-bonheur-nagoya
# 402   痩身ファスティング小顔専門店/BONHEUR-ボヌール-名古屋覚王山店のブログ  NaN  NaN  salon-bonheur-nagoya
# 403           たんちゃんのダイエット＆美容ブログ～ワークアウトで綺麗を作る～   女性  NaN            tantancoro
#
# ...

# %%
df['text'][27815]
# Out:
# '今日は電車で出掛けた。 久しぶりの遠出、明日が休みだからって理由と思いたったから。 人混みに行くと、人それぞれが自分の進む方へ進んでいくから、私も負けじと進む。それが、私は私で頑張って生きてるんだ…って思える。 待ちゆく人は短パンの人が多くて、私より健康体で 細さで言えば私の方が細いのに、私よりも幸せそう。 何で私の方が細いのに私は体型気にして辛いんだろう…ってBAD入ってしまった 他にもいろいろ考えてしまい辛くなってた時に、 手相占い！発見！ 吸い寄せられるように席に着席。 １５分、話を聞いて少し前向きになった。 結構当たっていて、後押ししてくれた。 ほんとに行き詰まった人の助けになる、占いやスピリチュアルがある理由が分かった気がした。 デパ地下でいろいろ見回って、どら焼き2種類３個ずつ購入 前だったらケーキや洋菓子、パンの中で迷ってたと思うけど今日はどら焼き一択だった。 最近クリーム系スイーツや洋菓子よりどら焼きが好き。 チョコレートより果物が良いと思うようになってきた。 好みって急に変わるものだなぁ～…、いや急でも無い気がする フードエリアに行くと吐き気がするのは健在だった。 これは拒食症の名残？これだから人と外出出来ないのだ、具合悪くなるから いろんな食べ物目にしても食欲沸かない、むしろ減退するのは痩せたい私には有り難い。 7月末にまた出掛けよう。その時はその場で美味しい物食べられると良いなぁ。 そして、それまでにどのくらい私のイメージするガリガリに近づいているかな。案外ガリガリになるまでは時間かからない気がしている。'

# %%
df[df['user'] == 'kanakramakid']
# Out:
#       blog_title sex  age          user  \
# 20560    ことりのブログ  女性  NaN  kanakramakid
# 20561    ことりのブログ  女性  NaN  kanakramakid
# 20562    ことりのブログ  女性  NaN  kanakramakid
# 20563    ことりのブログ  女性  NaN  kanakramakid
# 20564    ことりのブログ  女性  NaN  kanakramakid
# ...          ...  ..  ...           ...
# 27811    ことりのブログ  女性  NaN  kanakramakid
# 27812    ことりのブログ  女性  NaN  kanakramakid
# 27813    ことりのブログ  女性  NaN  kanakramakid
# 27814    ことりのブログ  女性  NaN  kanakramakid
# 27815    ことりのブログ  女性  NaN  kanakramakid
#
#                                                url        date  \
# 20560              https://ameblo.jp/kanakramakid/  2024-08-04
# 20561   https://ameblo.jp/kanakramakid/page-2.html  2024-08-03
# 20562   https://ameblo.jp/kanakramakid/page-3.html  2024-08-02
# 20563   https://ameblo.jp/kanakramakid/page-4.html  2024-08-01
# 20564   https://ameblo.jp/kanakramakid/page-5.html  2024-07-31
# ...                                            ...         ...
# ...

# %%
# ユーザ名が'kumiko-rabu'のデータを抽出
df_filtered[df_filtered['user'] == 'kanakramakid']
# Out:
#    blog_title sex  age          user  \
# 26    ことりのブログ  女性  NaN  kanakramakid
# 27    ことりのブログ  女性  NaN  kanakramakid
# 28    ことりのブログ  女性  NaN  kanakramakid
# 48    ことりのブログ  女性  NaN  kanakramakid
# 49    ことりのブログ  女性  NaN  kanakramakid
# 50    ことりのブログ  女性  NaN  kanakramakid
#
#                                             url        date       title  \
# 26   https://ameblo.jp/kanakramakid/page-8.html  2024-07-29          調整
# 27  https://ameblo.jp/kanakramakid/page-18.html  2024-07-21      日曜日ご褒美
# 28  https://ameblo.jp/kanakramakid/page-23.html  2024-07-17  ルーティンにしたがる
# 48   https://ameblo.jp/kanakramakid/page-7.html  2024-07-29          調整
# 49  https://ameblo.jp/kanakramakid/page-17.html  2024-07-21      日曜日ご褒美
# 50  https://ameblo.jp/kanakramakid/page-22.html  2024-07-17  ルーティンにしたがる
#
#                                                  text
# 26  昨日普段のカロリーより多く摂取したので 今朝は拒食モード炸裂でした。 食べるの嫌、カロリー摂...
# 27  今日は日曜日で食べても良い日。 スイーツとかドーナツとか3000kcal超え食べました。 今...
# ...

# %%
df_filtered['text'][26]
# Out:
# '昨日普段のカロリーより多く摂取したので 今朝は拒食モード炸裂でした。 食べるの嫌、カロリー摂取したくない で自分に聞いてみました。 「何kcalまでなら大丈夫？何kcal摂るのが嫌なの？」 700kcal台なら大丈夫かも…。 ということで、700kcal台で計算して食べる事が出来ました。 普段の摂取カロリーは700kcal台が許容範囲になってきてます。 でもこれだと確実にカロリー足りてないから、最近髪の毛がパサパサです 不健康極まりない(笑) 私は痩せたい、ガリガリになりたいので願ったり叶ったりですが、別に我慢してる感覚も無くシンプルに 食べるのが嫌。いらないって感じなんです。 私のカロリー源、今日はこれでした。 ロールケーキ美味しいなぁ、クリームがサッパリ系だったので食べることが出来ました。 摂食障害でこんな感じになってるのかは不明。 別にもうどっちでも良いんだ…、痩せさえすれば。 この食事量だとガリガリになれること確定なので メンタルは落ち着いてる。とはいえ、早くガリガリになりたい気持ちはあってモヤモヤ、元気出ない体力無いから疲れてます。 2週間後に久しぶりに人と会う約束をしたので、その頃には、今よりどのくらい痩せてるのかな〜ってちょっとだけ楽しみです。 倒れないように気を付けないとですけど'

# %%
# ユーザをすべて抽出
df_filtered['user'].unique()
# Out:
# array(['precious-being-day', 'happybeauty0628', 'kumiko-rabu',
#        'sweetjdog2002', 'hrmamadiet', 'kanakramakid', 'diet-neverdie',
#        'sachi-dahlia1515', 'marty2367', 'chiiharu-888', 'komachi-diet',
#        'ponpon1206ponpon', 'angui', 'minoyoga', '2scope', 'beauty102',
#        'akarisalontokyo', 'yukaslim', 'kyakusenseibishi', 'misarin1124',
#        'rino0707-47kg', 'patomugicha1036', 'ayaco-diet', 'zpamtak77',
#        'hachiko8-08', 'minikopateko813', 'katsuoldmen', 'shonangwapa',
#        'genryo2013', 'nyadiet', 'nobue-tanaka', 'jima30over', 'diet-0518',
#        'shimakabi-minion', 'koharubiyori5151', 'nekonekowhite',
#        'prettygoodsmile', 'gitamohikeroyo', 'na160373', 'hanaeri-slim',
#        'mieybodymake', 'muteki39', 'm1h0--438', 'ayayuiitsu',
#        'beruna-weblog', 'yuumi-tabeyase', 'bravefight', 'teshigoto44',
#        'aujud-official', 'a-t-z-noa', 'mjkcooking', 'kouji-kawano',
# ...

# %%
# ユーザ数を確認
print('ユーザ数：', len(df_filtered['user'].unique()), '人')
# Out:
# ユーザ数： 82 人
